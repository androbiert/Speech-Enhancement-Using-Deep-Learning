# %%
import os,sys
PROJECT_ROOT = os.path.abspath("..") 
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)


from src.dataset import SpeechEnhancementDataset

ds = SpeechEnhancementDataset("../data/N_TR", "../data/CL_TR", target_len=48000)
noisy, clean = ds[0]
print(noisy.shape, clean.shape)
# Out:
# torch.Size([1, 48000]) torch.Size([1, 48000])

# %%
# 1. Imports
import os
from src.preprocessing import *
from src.utils import load_audio
DATA_DIR = "../data"
NOISE_TRAIN_DIR = os.path.join(DATA_DIR, "N_TR")
CLEAN_TRAIN_DIR = os.path.join(DATA_DIR, "CL_TR")
NOISE_TEST_DIR = os.path.join(DATA_DIR, "N_TS")
CLEAN_TEST_DIR = os.path.join(DATA_DIR, "CL_TS")

# %%
audio = load_audio('..\data\CL_TS\p232_002.wav')
audio, _ = librosa.load('..\data\CL_TS\p232_002.wav', sr=48000)  # raw audio, no normalization
plt.plot(audio)
plt.title('p232_002.wav')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31516\4088643065.py:1: SyntaxWarning: invalid escape sequence '\d'
#   audio = load_audio('..\data\CL_TS\p232_002.wav')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31516\4088643065.py:2: SyntaxWarning: invalid escape sequence '\d'
#   audio, _ = librosa.load('..\data\CL_TS\p232_002.wav', sr=48000)  # raw audio, no normalization
# Text(0.5, 1.0, 'p232_002.wav')

# %% [markdown]
# # --
# ## 2. Explore Train Folders
# # -------------------------

# %%
print("=== Train Noisy ===")
train_noisy_files, train_noisy_durations, train_noisy_peaks = explore_folder(NOISE_TRAIN_DIR)
print("\n=== Train Clean ===")
train_clean_files, train_clean_durations, train_clean_peaks = explore_folder(CLEAN_TRAIN_DIR)

plot_duration_distribution(train_clean_durations, train_noisy_durations)
plot_peak_distribution(train_noisy_peaks, train_noisy_peaks)
# Out:
# === Train Noisy ===
# ...

# %%
# -------------------------
# 3. Explore Test Folders
# -------------------------
print("\n=== Test Noisy ===")
test_noisy_files, test_noisy_durations, test_noisy_peaks = explore_folder(NOISE_TEST_DIR)
print("\n=== Test Clean ===")
test_clean_files, test_clean_durations, test_clean_peaks = explore_folder(CLEAN_TEST_DIR)

plot_duration_distribution(test_clean_durations, test_noisy_durations)
plot_peak_distribution(test_clean_peaks, test_noisy_peaks)
test_noisy_peaks
# Out:
# === Test Noisy ===
# [ 0.02093506  0.02050781  0.02075195 ... -0.00515747 -0.00582886
#  -0.00408936]
# [-0.0173645  -0.01702881 -0.01651001 ...  0.00967407  0.01055908
#   0.00830078]
# [ 0.0171814   0.01733398  0.01831055 ... -0.03186035 -0.03155518
#  -0.03167725]
# [-0.04840088 -0.0350647  -0.02349854 ... -0.04949951 -0.05874634
#  -0.06729126]
# [-0.00714111 -0.00997925 -0.00881958 ...  0.02844238  0.02716064
#   0.02954102]
# [-0.03027344 -0.03158569 -0.03097534 ...  0.00561523  0.01062012
#   0.00784302]
# [-0.0149231  -0.01318359 -0.0128479  ...  0.00119019 -0.00387573
#  -0.00500488]
# [-0.15283203 -0.16467285 -0.1831665  ... -0.12567139 -0.10623169
#  -0.07791138]
# [-0.01300049 -0.01318359 -0.00784302 ... -0.04296875 -0.0355835
#  -0.04122925]
# [0.01345825 0.00686646 0.01196289 ... 0.01593018 0.01776123 0.01956177]
# Folder: ../data\N_TS
# Number of files: 10
# Duration (s): min=1.74, max=7.18, mean=4.47, std=1.70
# Peak amplitude: min=0.50, max=0.70, mean=0.54, std=0.05
# ...

# %%
# -------------------------
# 4. Plot Random Samples
# -------------------------
plot_random_samples(NOISE_TRAIN_DIR, CLEAN_TRAIN_DIR, n_samples=4)
# Out:
# Sample: p234_024.wav / p234_024.wav
# Sample: p234_043.wav / p234_043.wav
# Sample: p234_063.wav / p234_063.wav
# Sample: p234_067.wav / p234_067.wav
